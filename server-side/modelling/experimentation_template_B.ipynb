# %% [markdown]
# # **The goal here is to test the written loader, preprocessor and visualizer functions**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# # navigate to root directory of current file in order to access other files relatively
# %cd /content/drive/MyDrive/Colab\ Notebooks/project-seraphim/server-side/modelling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from PIL import Image

from utilities.loaders import (
    create_image_set,
    create_metrics_df,
    create_classified_df)

from utilities.preprocessors import (
    one_hot_encode,
    re_encode_sparse_labels,
    decode_one_hot,
    translate_labels,
    encode_image,
    standardize_image)

from utilities.visualizers import (
    data_split_metric_values,
    multi_class_heatmap,
    view_metric_values,
    view_classified_labels,
    view_label_freq,
    ModelResults,
    view_images,
    view_all_splits_results,
    show_image
)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Image Processing

# %%
train_gen, cross_gen, test_gen = create_image_set('./data/Micro_Organism/')

# %%
next(train_gen)

# %%
next(cross_gen)

# %%
train_gen.class_indices

# %%
list(train_gen.class_indices.keys())

# %%
images, labels = next(train_gen)

# %%
images[0]

# %%
labels[0]

# %%
images.shape

# %% [markdown]
# #### Here we have 5 batches of 128 examples for training

# %%
len(train_gen)

# %% [markdown]
# #### And here we have 4 batches of 32 example for validation and testing

# %%
len(cross_gen)

# %%
len(test_gen)

# %% [markdown]
# #### Here our training data went from 576 samples to 640 because of data augmentation, for validation from 114 to 32 * 4 or 128, and for testing from 126 to 32 * 4 or 128

# %%
view_images(train_gen, save_img=False)

# %%
img = Image.open('./data/Micro_Organism/Spherical_bacteria/Image_4.jpg')
show_image(img)

# %%
encoded_img = encode_image('./data/Micro_Organism/Spherical_bacteria/Image_4.jpg')
encoded_img

# %%
rescaled_img = standardize_image(encoded_img)
rescaled_img

# %%
rescaled_img.max()
